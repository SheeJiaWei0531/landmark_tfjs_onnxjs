# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("./data/processed_benchmark.csv")

# %%
df = df[~((df['pfld_106_init'] == "no H5 file") | (df['pfld_106_init'] == "not found") | (df['pfld_106_prediction'] == "no H5 file") | 
          (df['pfld_106_prediction'] == "not found") | (df['pfld_106_loading'] == "no H5 file") | (df['pfld_106_loading'] == "not found"))].reset_index(drop= True)

# %%
df = df.astype({'pfld_106_loading': float, 'pfld_106_init': float, 'pfld_106_prediction': float})

# %%
df.describe()
# Out:
#        liveness_result_code  pfld_106_loading  pfld_106_init  \
# count          23600.000000      23600.000000   23600.000000
# mean            4138.017161       1674.967881     542.102881
# std            11884.367063       2068.364345     572.985868
# min              200.000000         39.000000      23.000000
# 25%              200.000000        702.000000     247.000000
# 50%              200.000000       1076.000000     390.000000
# 75%              200.000000       1849.000000     672.000000
# max            40004.000000      43681.000000   23063.000000
#
#        pfld_106_prediction
# count         23600.000000
# mean            279.340127
# std             362.576098
# min              16.000000
# 25%              97.000000
# 50%             159.000000
# 75%             394.000000
# max           23055.000000
